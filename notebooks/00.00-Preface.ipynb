# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/kep.png" height=75 width=75>
# *This notebook uses routines from [PyKE](http://github.com/keplerGO/PyKE/) which is documented [here](http://pyke.keplerscience.org/). You can find these notebooks on [GitHub](https://github.com/christinahedges/k2torials)*

# %% [markdown]
# <!--NAVIGATION-->
# | [Contents](index.ipynb) | [Basics](01.00-Basics.ipynb) >

# %% [markdown]
# # Preface

# %% [markdown]
# The [Kepler mission](https://keplerscience.arc.nasa.gov) and later K2 mission have provided the astronomy community with long baseline time series of hundreds of thousands of stars. Using this dataset you can study variable stars, supernovae and exoplanets!
#
# This set of notebooks is designed to show you how to work with the Kepler data using PyKE to find and characterize exoplanets. While PyKE will work for K2 data, extra steps must be taken to detrend the spacecraft motion. This will be discussed in later tutorials.

# %% [markdown]
# ### PyKE
#
# [PyKE](http://github.com/keplerGO/PyKE/) is a set of routines to process time series data taken from the Kepler mission and later K2 mission. The full package is documented [here](http://pyke.keplerscience.org/) and can be installed simply with
# ```
# $ pip install pyketools
# ```
#
# PyKE comes with both Python routines and command line tools.

# %% [markdown]
# ## Use the tools you are comfortable with!
#
# This notebook is designed to help you with using [PyKE](https://github.com/keplerGO/PyKE/) and other libraries for exoplanet science. There are usually two routes that you can take in most notebooks to follow along. For those more comfortable with *Python* code there are implementations directly in Python, calling in PyKE routines as modules.
#
# Below there are two examples of plotting a light curve using PyKE. The first one uses a python implementation that imports the *kepdraw* module and then runs it. This opens an interactive plotting window. (We've used the %matplotlib inline command to make sure all plot windows run inside the notebook.)
#
# ### Python Kepdraw

# %%
# %matplotlib inline
from pyke import kepdraw
kepdraw('data/kplr006922244-2010078095331_llc.fits')
# Out:
# Found the following flux columns: SAP_FLUX, SAP_FLUX_ERR, PDCSAP_FLUX, PDCSAP_FLUX_ERR
# Using data column PDCSAP_FLUX on the plot...
# Writing output file data/kplr006922244-2010078095331_llc-kepdraw.png...

# %% [markdown]
# Alternately you can use PyKE as command line tools. You would do this from your terminal. This is a method some users may be more familiar and comfortable with. This process might look something like the image below. In this case we have also run *kepdraw*, but this time from the command line. (Note in this example we have turned the interactive plotting off with the *--non-interactive* keyword.)

# %% [markdown]
# <img align="center" style="padding-right:10px;" src="figures/terminalexample.png" width=700>

# %% [markdown]
# In these notebooks we will demonstrate how to use command line tools using 'bash' cells like the ones below. These will be highlighted in the text. The cell below performs exactly the same function as the ones above.
#
# ### Command Line Kepdraw

# %%
# %%bash
# kepdraw data/kplr006922244-2010078095331_llc.fits --non-interactive
# Out:
# Found the following flux columns: SAP_FLUX, SAP_FLUX_ERR, PDCSAP_FLUX, PDCSAP_FLUX_ERR
# Using data column PDCSAP_FLUX on the plot...
# Writing output file data/kplr006922244-2010078095331_llc-kepdraw.png...

# %% [markdown]
# # Lessons in this Notebook
#
# In this set of notebooks we will cover a range of topics, starting at the **basics**. This will include how to obtain data from the Kepler and K2 missions, how to clean that data and plot it. We will then cover how to clean exoplanet light curves, how to find exoplanets and how to vet them.

# %% [markdown]
# <!--NAVIGATION-->
# | [Contents](index.ipynb) | [Basics](01.00-Basics.ipynb) >
