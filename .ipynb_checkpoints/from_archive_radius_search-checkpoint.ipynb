# %%
# %load_ext autoreload
# %autoreload 2
from lightkurve import KeplerLightCurveFile, KeplerTargetPixelFile
import matplotlib.pyplot as plt
import numpy as np

# %%
#%debug
lcfs = KeplerLightCurveFile.from_archive('Kepler-10', quarter=3, radius=200, targetlimit=5)
# Out:
# Found 5 File(s)
# INFO: Found cached file ./mastDownload/Kepler/kplr011904151_lc_Q111111110111011101/kplr011904151-2009350155506_llc.fits with expected size 466560. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011904148_lc_Q011111110111011101/kplr011904148-2009350155506_llc.fits with expected size 466560. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011904099_lc_Q011111110111011101/kplr011904099-2009350155506_llc.fits with expected size 466560. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011904085_lc_Q111111110111011101/kplr011904085-2009350155506_llc.fits with expected size 466560. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011904071_lc_Q001111110111011101/kplr011904071-2009350155506_llc.fits with expected size 466560. [astroquery.query]

# %%
fig, ax = plt.subplots()
for lcf in lcfs:
    lcf.PDCSAP_FLUX.plot(ax=ax)

# %%
from lightkurve import mast

# %%
len(mast.search_kepler_products(11904151, quarter=11)) == 1
# Out:
# True

# %%
c91 = mast.search_kepler_products(200068780, quarter=91)
c92 = mast.search_kepler_products(200068780, quarter=92)
assert(len(c91) == 1)
assert(len(c91) == len(c92))
assert(~np.any(c91['description'] == c92['description']))
assert(~np.any(c91['dataURI'] == c92['dataURI']))
# Out:
# True

# %%
len(c91) == len(c92)
# Out:
# True

# %%
~np.any(c91['description'] == c92['description'])
# Out:
# True

# %%
~np.any(c91['dataURI'] == c92['dataURI'])
# Out:
# True

# %%
c91 = mast.search_kepler_products(200068780, quarter=101, targetlimit=3)
c92 = mast.search_kepler_products(200068780, quarter=102, targetlimit=3)

# %%
mast.search_kepler_products(-999)
# Out:
# ---------------------------------------------------------------------------
# ResolverError                             Traceback (most recent call last)
# ~/K2/repos/lightkurve/lightkurve/mast.py in search_products(target, radius)
#      83                                           radius='{} arcsec'.format(radius),
# ---> 84                                           project=["Kepler", "K2"])
#      85     except ResolverError as exc:
#
# ~/miniconda3/lib/python3.6/site-packages/astroquery/utils/class_or_instance.py in f(*args, **kwds)
#      24             if obj is not None:
# ---> 25                 return self.fn(obj, *args, **kwds)
#      26             else:
#
# ~/miniconda3/lib/python3.6/site-packages/astroquery/utils/process_asyncs.py in newmethod(self, *args, **kwargs)
#      25
# ---> 26             response = getattr(self, async_method_name)(*args, **kwargs)
#      27             if kwargs.get('get_query_payload') or kwargs.get('field_help'):
#
# ...
